# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np
import librosa as ls
import IPython.display as ipd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import partial
import warnings
from functools import partial

# Bring your packages onto the path
import sys, os
sys.path.append('../')
from file_operations import to_pickle, read_pickle
from preprocessing import get_MFCC, split_signal, sound_pipeline, normalize_array
from preprocessing import overlay_noise, add_padding_to_sound, encode_labels, invert_encode

# Ignoring warnings
warnings.filterwarnings('ignore')

# Ensuring autoreload of changes in submodules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Loading prepreocessed MFCC data

# %%
data = read_pickle('sample_rate2205_num_mfcc13_n_fft2048_hop_length512.pickle')

# %% [markdown]
# ### One hot encoding command labels

# %%
commands = ['go', 'left', 'right', 'stop']
label_encoder = LabelEncoder()
label_encoder.fit(commands)

X = np.array(data['X'])[:,:,:,np.newaxis]
y = encode_labels(data['labels'], label_encoder)

label_encoder.classes_
# Out:
# array(['go', 'left', 'right', 'stop'], dtype='<U5')

# %%
X.shape
# Out:
# (104192, 13, 44, 1)

# %%
idd = np.random.randint(0,len(data['sounds']))
print(y[idd], invert_encode(y[idd], label_encoder))
ipd.Audio(data['sounds'][idd],rate=22050)
# Out:
# [0. 0. 1. 0.] ['right']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Splitting the data for training and testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=5,shuffle=True)

# %% [markdown]
# ### Configuring CNN model training and fitting it to the data

# %%
from cnn_clf_model import get_model, train
import tensorflow as tf

epochs=9 
batch_size=64
patience=0
earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)
mcp_save = tf.keras.callbacks.ModelCheckpoint('mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='min')

model = get_model(X_train.shape[1:], num_outputs=4, learning_rate=0.0001)
# train model
history = model.fit(X_train,
                    y_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_test, y_test),
                    callbacks=[earlystop_callback,mcp_save])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 11, 42, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 11, 42, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 21, 64)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 19, 32)         18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 19, 32)         128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 10, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 9, 32)          4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 9, 32)          128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                10304
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 34,308
# Trainable params: 34,052
# Non-trainable params: 256
# _________________________________________________________________
# Train on 69808 samples, validate on 34384 samples
# Epoch 1/9
# 69808/69808 [==============================] - 8s 112us/sample - loss: 0.6720 - accuracy: 0.7664 - val_loss: 0.3454 - val_accuracy: 0.8977
# Epoch 2/9
# 69808/69808 [==============================] - 6s 87us/sample - loss: 0.2643 - accuracy: 0.9272 - val_loss: 0.2560 - val_accuracy: 0.9291
# Epoch 3/9
# 69808/69808 [==============================] - 32s 462us/sample - loss: 0.2047 - accuracy: 0.9449 - val_loss: 0.3432 - val_accuracy: 0.8950
# Epoch 4/9
# 69808/69808 [==============================] - 32s 460us/sample - loss: 0.1758 - accuracy: 0.9549 - val_loss: 0.3734 - val_accuracy: 0.8876
# Epoch 5/9
# 69808/69808 [==============================] - 32s 462us/sample - loss: 0.1562 - accuracy: 0.9604 - val_loss: 0.1531 - val_accuracy: 0.9618
# Epoch 6/9
# 69808/69808 [==============================] - 10s 147us/sample - loss: 0.1442 - accuracy: 0.9638 - val_loss: 0.2966 - val_accuracy: 0.9162
# Epoch 7/9
# 69808/69808 [==============================] - 4s 55us/sample - loss: 0.1323 - accuracy: 0.9681 - val_loss: 0.2207 - val_accuracy: 0.9350
# Epoch 8/9
# 69808/69808 [==============================] - 4s 55us/sample - loss: 0.1252 - accuracy: 0.9693 - val_loss: 0.1704 - val_accuracy: 0.9537
# Epoch 9/9
# 69808/69808 [==============================] - 4s 56us/sample - loss: 0.1167 - accuracy: 0.9719 - val_loss: 0.1293 - val_accuracy: 0.9661

# %%
partial_mffc = partial(get_MFCC,sample_rate=22050,num_mfcc=13, n_fft=2048, hop_length=512, scaled = False)

# %%
# sound = sound[:sr]
sound = sound[sr*83:]

# %%
85000+sr
# Out:
# 107050

# %%
s = 127050
ipd.Audio(sound[s:s+sr],rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sound, sr = ls.load('test.wav')
stop = sound[6000:sr+6000]
left = sound[2*sr+6000:3*sr+6000]
right = sound[85000:85000+sr]
go = sound[127050:127050+sr]

# %%
from SoundCommandClf import SoundCommandClf

# %%
clf = SoundCommandClf()
# Out:
# Model model.hdf5 has been loaded successfully!

# %%
# %%timeit
clf.classify_rec(stop)
# Out:
# 18.5 ms ± 179 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-21-991c6a44a26c> in <module>
# ----> 1 clf.classify_rec(stop)
#
# D:\Projekty\studia\sound\sound_commands_clf\SoundCommandClf.py in classify_rec(self, rec)
#      97         x = self.preprocess_rec(rec)
#      98         y_hat = self.model.predict(x)
# ---> 99         predicted_class = self.encode_pred(y_hat)
#
# D:\Projekty\studia\sound\preprocessing.py in invert_encode(y_hat, label_encoder)
#     114
#     115 def invert_encode(y_hat, label_encoder):
# --> 116     return label_encoder.inverse_transform([np.argmax(y_hat)])
#     117
#     118
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\sklearn\preprocessing\_label.py in inverse_transform(self, y)
#     290         y : numpy array of shape [n_samples]
#     291         """
# --> 292         check_is_fitted(self)
#     293         y = column_or_1d(y, warn=True)
#     294         # inverse transform of empty array is empty array
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This LabelEncoder instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
sound, sr = ls.load('right.wav')
sound = sound[:sr]
ipd.Audio(sound,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Out:
# 22050

# %%
# padded = add_padding_to_sound(sound)
mfcc = partial_mffc(go)
mfcc = normalize_array(mfcc)
# mfcc = mfcc[np.newaxis,:,:,np.newaxis]
invert_encode(model.predict(mfcc[np.newaxis,:,:,np.newaxis]))
# Out:
# array(['go'], dtype='<U5')

# %%
# Out:
# array([[1.9546379e-21, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00]],
#       dtype=float32)

# %%
# Out:
# array(['go'], dtype='<U5')
